# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the inbuilt Titanic dataset
titanic = sns.load_dataset('titanic')

# Plotting boxplot: Age distribution with respect to gender and survival
plt.figure(figsize=(10, 6))
sns.boxplot(data=titanic, x='sex', y='age', hue='survived')

# Adding title and labels
plt.title('Age Distribution by Gender and Survival Status')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.legend(title='Survived')

# Show the plot
plt.show()

# %%
'''
1.Median age of male survivors tends to be slightly lower compared to non-survivors.
2.Median age of female survivors tends to be slightly upper compared to non-survivors.
3.Outliers are present (ages far from median), especially among male non-survivors.
